# %% [markdown]
# ### Drawing normal Graph

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Normal line Graph

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='blue',linewidth=2,linestyle='dotted')

# %%
# Format String line Graph

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green',marker='D',linestyle='-')

# %%
# Format String line Graph

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='red',marker='*',linestyle='--')

# %%
# Format String line Graph

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.scatter(x,y,color='red',marker='*',linestyle='--')

# %%
# Using Axes Label, Legend, Grid
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,51,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days,max_t,color='red',marker='*',linestyle='--',label='Max')
plt.plot(days,min_t,color='blue',marker='+',linestyle='-',label='Min')
plt.plot(days,avg_t,color='black',marker='D',linestyle='--',label='Aveg')

plt.legend(loc='best', shadow=True)
plt.grid()

# %%
# Using Axes Label, Legend, Grid
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,51,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.stackplot(days,min_t,avg_t,min_t,labels=('min','avg','max'))

plt.legend(loc='best', shadow=True)
plt.grid()

# %%
# Quadratic Graph Problems
# Draw the quadratic graph -x**2 + 3*x + 5

# %%
# Drawing a quadratic graph (Example 2)
def quad_y(x):
    y_vals = -x**2 + 3*x + 5
    #y_vals = (x-2)8*2
    return y_vals

x_vals = list(range(-3,7))
y_vals = list(map(quad_y,x_vals))

print(f'The values of x:{x_vals}')
print(f'The values of y:{y_vals}')
# Out:
# The values of x:[-3, -2, -1, 0, 1, 2, 3, 4, 5, 6]
# The values of y:[-13, -5, 1, 5, 7, 7, 5, 1, -5, -13]

# %%
plt.plot(x_vals, y_vals, color='brown', marker='D',linestyle='-')
plt.xticks(x_vals)
plt.xlabel('x_values')
plt.ylabel('y_values')
plt.title('Quadratic graph of -x**2 + 3*x + 5')
# Add horizontal line at y=0
plt.axhline(y=0, color='red', linestyle='--')
# Add vertical line at x=-1.2
plt.axvline(x=-1.2, color='green', linestyle='--')
plt.grid()

# %%
# Solution
# The plot where the curve crosses the black line is your solution
# The solution are points: x= -1.2, x= 4.2

# %%
# Drawing Bar Chart
company = ['Google','Amazon','Microsoft','Facebook']
revenue =[90,136,89,27] # in Billions

xpos = np.arange(len(company))

plt.xticks(xpos, company)
plt.xlabel('Company')
plt.ylabel('Revenue ($Bn)')
plt.title('U.S Stocks Report')

plt.bar(xpos,revenue,label='Revenue')
plt.legend()

# %%
# Drawing Bar Chart
company = ['Google','Amazon','Microsoft','Facebook']
revenue = [90,136,89,27] # in Billions
profit = [40,20,34,12]

xpos = np.arange(len(company))

plt.xticks(xpos, company)
plt.xlabel('Company')
plt.ylabel('Revenue ($Bn)')
plt.title('U.S Stocks Report')

plt.bar(xpos,revenue,label='Revenue')
plt.bar(xpos,profit,label='Profit')
plt.legend()

# %%
# Drawing Vertical Bar Chart
company = ['Google','Amazon','Microsoft','Facebook']
revenue = [90,136,89,27] # in Billions
profit = [40,20,34,12]

xpos = np.arange(len(company))

plt.xticks(xpos, company)
plt.xlabel('Company')
plt.ylabel('Revenue ($Bn)')
plt.title('U.S Stocks Report')

plt.bar(xpos-0.2, revenue, width=0.4, label='Revenue')
plt.bar(xpos+0.2, profit, width=0.4, label='Profit')
plt.legend()
plt.grid()

# %%
# Drawing Bar Chart
company = ['Google','Amazon','Microsoft','Facebook']
revenue = [90,136,89,27] # in Billions

ypos = np.arange(len(company))

colors = ['green', 'blue', 'orange', 'red']
plt.yticks(ypos, company)
plt.ylabel('Company')
plt.xlabel('Revenue ($Bn)')
plt.title('U.S Stocks Report')

plt.barh(ypos, revenue, height=0.8, color=colors, label='Revenue')
plt.legend()

#plt.grid()
plt.show()

# %%
# Drawing Horizontal Bar Chart
company = ['Google','Amazon','Microsoft','Facebook']
revenue = [90,136,89,27] # in Billions
profit = [40,20,34,12]

ypos = np.arange(len(company))

plt.yticks(ypos, company)
plt.xlabel('Revenue ($Bn)')
plt.ylabel('Company')
plt.title('U.S Stocks Report')

plt.barh(ypos-0.2, revenue, height=0.4, label='Revenue')
plt.barh(ypos+0.2, profit, height=0.4, label='Profit')
plt.legend()

plt.show()

# %% [markdown]
# ### Histogram

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#Populatuing the blood sugar level into a list 
sugar_level =[113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 129]

plt.hist(sugar_level, bins=[80,100,125,150], rwidth=0.95,color='red')
plt.grid()

# %%
#Populatuing the blood sugar level into a list 
men_sugar_level = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 129]
women_sugar_level = [67, 98, 89, 120, 133, 150, 84, 69,89,79, 120, 112, 100]

plt.xlabel('Sugar range')
plt.ylabel('Total Number of Patients')
plt.title('Blood Sugar Analysis')
plt.hist([men_sugar_level, women_sugar_level], bins=[60,80,100,125,150], 
        rwidth=0.95, color=['blue','pink'], label=['Men','Women'])
plt.legend()
plt.grid()

# %% [markdown]
# ### stackplotting Horizontal Histogram

# %%
#Populatuing the blood sugar level into a list 
men_sugar_level = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 129]
women_sugar_level = [67, 98, 89, 120, 133, 150, 84, 69,89,79, 120, 112, 100]

plt.ylabel('Sugar range')
plt.xlabel('Total Number of Patients')
plt.title('Blood Sugar Analysis')
plt.hist([men_sugar_level, women_sugar_level], bins=[80,100,125,150], rwidth=0.95, 
         color=['green','black'], label=['Men','Women'],orientation='horizontal')
plt.legend()

# %% [markdown]
# ### Working with Pie Charts

# %%
## Populating the values
expenses_label = ['Rent', "Food", 'Phone/Internet','Car','Other Bills']
expenses_amount = [1400, 600, 300, 410, 250]

plt.axis('equal')
plt.pie(expenses_amount, labels=expenses_label, radius=1.5)
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
## Adding percentages to the Amount
expenses_label = ['Rent', "Food", 'Phone/Internet','Car','Other Bills']
expenses_amount = [1400, 600, 300, 410, 250]

plt.axis('equal')
plt.pie(expenses_amount, labels=expenses_label, radius=0.8, autopct='%0.2f%%')
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
## Adding percentages to the Amount with little Explosion
expenses_label = ['Rent', "Food", 'Phone/Internet','Car','Other Bills']
expenses_amount = [1400, 600, 300, 410, 250]

plt.axis('equal')
plt.pie(expenses_amount, labels=expenses_label, radius=0.8, autopct='%0.2f%%', shadow=True,
       explode=[0,0.1,0.1,0,0], startangle=180)
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
## Saving your figures as a file

expenses_label = ['Rent', "Food", 'Phone/Internet','Car','Other Bills']
expenses_amount = [1400, 600, 300, 410, 250]

plt.axis('equal')
plt.pie(expenses_amount, labels=expenses_label, radius=1.2, autopct='%0.2f%%',
       explode=[0,0.1,0.1,0,0])
plt.savefig('my_piechart.tiff', bbox_inches='tight',pad_inches=0.2, transparent=True)
# other picture formats: .jpg, .png, .pdf
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
pwd
# Out:
# 'C:\\CHM Python Class\\2024_02 KC PYTHON'

# %%
# Saving your figures as a file

expenses_label = ['Rent', "Food", 'Phone/Internet', 'Car', 'Other Bills']
expenses_amount = [1400, 600, 300, 410, 250]
plt.axis('equal')
plt.pie(expenses_amount, labels=expenses_label, radius=1.2, autopct= '%0.2f%%', explode = [0, 0.1,0.1,0,0])
file_path = r'C:\CHM Python Class\2024_02 KC PYTHON\my_piechart.png'
plt.savefig(file_path, bbox_inches = 'tight', pad_inches = 0.2, transparent=True)
# other picture formats: .jpg, .png, .pdf
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
pwd
# Out:
# 'C:\\CHM Python Class\\2024_02 KC PYTHON'

# %% [markdown]
# ## Plotly

# %% [markdown]
# Plotly allows you to create over 40 beautiful interactive web-based visualizations that can be displayed in Jupyter notebooks or saved to HTML files. It is widely used to stackplot scientific, statistical and financial data.

# %% [markdown]
# You can install using Anaconda under the environment tab by searching for Plotly. You'll also need Cufflinks and a few other packages that you can install by running : conda install -c conda-forge cufflinks-py in your command line or terminal. Also you can use the commands pip install plotly and pip install cufflinks. Cufflinks connects Plotly to Pandas.

# %%
# Installing the cufflinks modules
# !pip install cufflinks

# %%
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %% [markdown]
# ## Line stackplot

# %%
# Plot the value of a dollar invested over time
# Use included Google price data to make one plot
df_stocks = px.data.stocks()
px.line(df_stocks, x='date', y='GOOG', labels={'x':'Date', 
                                               'y':'Value of Dollar'})

# %%
df_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    105 non-null    object
#  1   GOOG    105 non-null    float64
#  2   AAPL    105 non-null    float64
#  3   AMZN    105 non-null    float64
#  4   FB      105 non-null    float64
#  5   NFLX    105 non-null    float64
#  6   MSFT    105 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 5.9+ KB

# %%
# Selecting column headers for float
float_data_columns = list(df_stocks.select_dtypes(include='float').columns)
print(float_data_columns)
# Out:
# ['GOOG', 'AAPL', 'AMZN', 'FB', 'NFLX', 'MSFT']

# %%
for column in float_data_columns:
    df_stocks[column] = df_stocks[column].astype ('float16') #

df_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    105 non-null    object
#  1   GOOG    105 non-null    float16
#  2   AAPL    105 non-null    float16
#  3   AMZN    105 non-null    float16
#  4   FB      105 non-null    float16
#  5   NFLX    105 non-null    float16
#  6   MSFT    105 non-null    float16
# dtypes: float16(6), object(1)
# memory usage: 2.2+ KB

# %%
# Selecting column headers for integers
int_data_columns = list(df_stocks.select_dtypes(include='int').columns) # number, float, bool, object, datetime
print(int_data_columns)
# Out:
# []

# %%
# Make multiple line plots
px.line(df_stocks, x='date', y=['GOOG','AAPL', 'MSFT'], labels={'x':'Date', 
                                                        'y':'Value of Dollar'},
       title='Apple vs Google vs Microsoft')

# %%
# Multiple plots
import numpy as np

r_x1 = np.linspace(0,1,100)
r_y0 = np.random.randn(100) + 5
r_y1 = np.random.randn(100) - 5
r_y2 = np.random.randn(100)

fig = go.Figure()
# There are many line styles
fig.add_trace(go.Scatter(x=r_x1, y=r_y0, mode='lines', name='Rand 1'))
fig.add_trace(go.Scatter(x=r_x1, y=r_y1, mode='lines+markers', name='Rand 2'))
fig.add_trace(go.Scatter(x=r_x1, y=r_y2, mode='markers', name='Rand 3'))

fig.show()

# %% [markdown]
# ## Add Details to Plot

# %%
import pandas as pd

aapl_df = pd.read_csv('AAPL.csv')
x = aapl_df['Date']
y = aapl_df['Adj Close']
aapl_df
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y))
fig.update_xaxes(
    rangeslider_visible=True, title='Zoom on Dates Using Slider')
fig.update_yaxes(title="Stock Price (USD)")

# %% [markdown]
# ## More Details

# %%
msft_df = pd.read_csv('MSFT.csv')
x = msft_df['Date']
y = msft_df['Adj Close']
msft_df
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y))

# Add a range slider with buttons for dates
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=10,
                     label="10D",
                     step="day",
                     stepmode="backward"),
                dict(count=1,
                     label="1M",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6M",
                     step="month",
                     stepmode="todate"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1Y",
                     step="year",
                     stepmode="backward"),
                dict(label="All", step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)
fig.update_yaxes(title="Stock Price (USD)")

# %% [markdown]
# ## Candlestick Plots

# %%
# Candlestick charts are useful because they show the open and close in the
# wide part "Real Body" and the high and low using the Shadows or Wicks.
# They can be used to sense emotion in a stock in the near term.
x = aapl_df['Date']
close = aapl_df['Adj Close']
high = aapl_df['High']
low = aapl_df['Low']
openp = aapl_df['Open']

fig = go.Figure()

fig.add_trace(go.Candlestick(x=x, high=high, low=low, 
                             open=openp, close=close))



fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=10,
                     label="10D",
                     step="day",
                     stepmode="backward"),
                dict(count=1,
                     label="1M",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6M",
                     step="month",
                     stepmode="todate"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1Y",
                     step="year",
                     stepmode="backward"),
                dict(label="All", step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)
fig.update_layout(xaxis_title="Dates", yaxis_title="Stock Price (USD)", 
                  title="Apple Candlestick Chart")

fig.show()

# %%
## Candlestick Plots with Annotations

# %%
# Candlestick charts are useful because they show the open and close in the
# wide part "Real Body" and the high and low using the Shadows or Wicks.
# They can be used to sense emotion in a stock in the near term.
x = aapl_df['Date']
close = aapl_df['Adj Close']
high = aapl_df['High']
low = aapl_df['Low']
openp = aapl_df['Open']

fig = go.Figure()

fig.add_trace(go.Candlestick(x=x, high=high, low=low, 
                             open=openp, close=close))



fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=10,
                     label="10D",
                     step="day",
                     stepmode="backward"),
                dict(count=1,
                     label="1M",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6M",
                     step="month",
                     stepmode="todate"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1Y",
                     step="year",
                     stepmode="backward"),
                dict(label="All", step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)
fig.update_layout(xaxis_title="Dates", yaxis_title="Stock Price (USD)", 
                  title="Apple Candlestick Chart")

# Add an annotation
fig.update_layout(annotations=[dict(x='2020-02-21', y=85, 
                                    text='Pandemic Effects Market',
                                   xanchor='right')])
# Add line defining an area
fig.update_layout(shapes=[dict(x0='2020-02-21', x1='2020-04-06', 
                                    y0=0, y1=1)])
# Add a rectangle
# fig.add_shape(type="rect",
#     x0='2020-02-21', y0=0, x1='2020-04-06', y1=145,
#     line=dict(
#         color="RoyalBlue",
#         width=2,
#     ),
#     fillcolor="LightSkyBlue",
# )

# Add a vertical rectangle with opacity
fig.add_vrect(
    x0='2020-02-21', x1='2020-04-06',
    fillcolor="LightSalmon", opacity=0.5,
    layer="below", line_width=0,
)

fig.show()

# %% [markdown]
# ## Open-High-Low-Close (OHLC) Chart

# %%
# While a candlestick chart has a rectangle representing the open and close
# An OHLC chart shows all 4 data points using ticks and when the opening
# and closing prices are fall apart that shows momentum up or down
# The tick on the left is the opening price and the left is the close
fig = go.Figure()

fig.add_trace(go.Ohlc(x=x, high=high, low=low, open=openp, close=close))

fig.show()

# %% [markdown]
# ## Multiple Plots

# %%
fig = go.Figure()

fig.add_trace(go.Ohlc(x=x, high=high, low=low, open=openp, close=close))

a_x = aapl_df['Date']
a_y = aapl_df['Adj Close']
fig.add_trace(go.Scatter(x=a_x, y=a_y,line=dict(color='blue', 
                                                width=1.5, dash="dot")))

fig.show()

# %% [markdown]
# ## Scatter Plots

# %%
x = np.arange(0,50,2)
y = np.arange(0,50,2)

# Create a figure to which I'll add plots
fig = go.Figure()

# Markers just shows the dots
fig.add_trace(go.Scatter(x=x, y=y, mode='markers'))

fig.show()

# %%
# Use included Iris data set
df_iris = px.data.iris()
# Create a scatter plot by defining x, y, different color for count of provided
# column, size based on supplied column and additional data to display on hover
px.scatter(df_iris, x="sepal_width", y="sepal_length", color="species",
                 size='petal_length', hover_data=['petal_width'])

# Create a customized scatter with black marker edges with line width 2, opaque
# and colored based on width. Also show a scale on the right
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df_iris.sepal_width, y=df_iris.sepal_length,
    mode='markers',
    marker_color=df_iris.sepal_width,
    text=df_iris.species,
    marker=dict(showscale=True)))
fig.update_traces(marker_line_width=2, marker_size=10)

# Working with a lot of data use Scattergl
fig = go.Figure(data=go.Scattergl(
    x = np.random.randn(100000),
    y = np.random.randn(100000),
    mode='markers',
    marker=dict(
        color=np.random.randn(100000),
        colorscale='Viridis',
        line_width=1)))
fig

# %% [markdown]
# ## Histogram

# %%
# Plot histogram based on rolling 2 dice
dice_1 = np.random.randint(1,7,5000)
dice_2 = np.random.randint(1,7,5000)
dice_sum = dice_1 + dice_2
# bins represent the number of bars to make
# Can define x label, color, title
# marginal creates another plot (violin, box, rug)
fig = px.histogram(dice_sum, nbins=11, labels={'value':'Dice Roll'},
             title='5000 Dice Roll Histogram', marginal='violin',
            color_discrete_sequence=['green'])

fig.update_layout(
    xaxis_title_text='Dice Roll',
    yaxis_title_text='Dice Sum',
    bargap=0.2, showlegend=False
)

# Stack histograms based on different column data
df_tips = px.data.tips()
px.histogram(df_tips, x="total_bill", color="sex")

# %%
# How to Handle Website with HTTPError

# %%
import pandas as pd
import numpy as np
c_data = pd.read_xml("https://trumpexcel.com/excel-functions/)")
c_data
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 c_data = pd.read_xml("https://trumpexcel.com/excel-functions/)")
#       4 c_data
#
# File C:\CHM Python Class\myenv_pydata\Lib\site-packages\pandas\io\xml.py:1160, in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend)
#     888 r"""
#     889 Read XML document into a :class:`~pandas.DataFrame` object.
#     890
#    (...)   1156 1      1  <NA>  4.5  False  b 2019-12-31
#    1157 """
#    1158 check_dtype_backend(dtype_backend)
# -> 1160 return _parse(
#    1161     path_or_buffer=path_or_buffer,
#    1162     xpath=xpath,
#    1163     namespaces=namespaces,
#    1164     elems_only=elems_only,
# ...

# %%
import pandas as pd
import requests

base_site = 'https://trumpexcel.com/excel-functions/'

r = requests.get(base_site)
r.status_code

tables = pd.read_html(r.text)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6160\2263987563.py:9: FutureWarning:
#
# Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.

# %%
tables[2]
# Out:
#              Excel Function                                        Description
# 0     Excel COLUMN Function  Excel COLUMN function can be used when you wan...
# 1    Excel COLUMNS Function  Excel COLUMNS function can be used when you wa...
# 2    Excel HLOOKUP Function  Excel HLOOKUP function is best suited for situ...
# 3      Excel INDEX Function  Excel INDEX function can be used when you have...
# 4   Excel INDIRECT Function  Excel INDIRECT function can be used when you h...
# 5      Excel MATCH Function  Excel MATCH function can be used when you want...
# 6     Excel OFFSET Function  Excel OFFSET function can be used when you wan...
# 7        Excel ROW Function  Excel ROW Function function can be used when y...
# 8       Excel ROWS Function  Excel ROWS Function can be used when you want ...
# 9    Excel VLOOKUP Function  Excel VLOOKUP function is best suited for situ...
# 10   Excel XLOOKUP Function  Excel XLOOKUP function is a new function for O...
# ...

# %%
# How to merge all the 6 tables on the website

df_row_merged = pd.concat([tables[0], tables[1],tables[2],tables[3],tables[4],tables[5]], ignore_index=True)

# %%
df_row_merged
# Out:
#                Excel Function  \
# 0         Excel DATE Function
# 1   ​Excel DATEVALUE Function
# 2          Excel DAY Function
# 3         Excel HOUR Function
# 4       Excel MINUTE Function
# ..                        ...
# 75        Excel TEXT Function
# 76        Excel TRIM Function
# 77       Excel UPPER Function
# 78      Excel REGEX Functions
# 79   Excel TRANSLATE Function
#
#                                           Description
# 0   Excel DATE function can be used when you want ...
# 1   Excel DATEVALUE function is best suited for si...
# 2   Excel DAY function can be used when you want t...
# 3   Excel HOUR function can be used when you want ...
# 4   Excel MINUTE function can be used when you wan...
# ..                                                ...
# 75  Excel TEXT function can be used when you want ...
# 76  Excel TRIM function can be used when you want ...
# 77  Excel UPPER function can be used when you want...
# ...

# %%
df_row_merged.to_excel("Jane Excel scripts.xlsx")
